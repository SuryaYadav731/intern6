# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("E:\\project\\17\\Customer data.csv")
df
# Out:
#        CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0               1   22  Female      25               14              4
# 1               2   41  Female      28               28              7
# 2               3   47    Male      27               10              2
# 3               4   35    Male       9               12              5
# 4               5   53  Female      58               24              9
# ...           ...  ...     ...     ...              ...            ...
# 64369       64370   45  Female      33               12              6
# 64370       64371   37    Male       6                1              5
# 64371       64372   25    Male      39               14              8
# 64372       64373   50  Female      18               19              7
# 64373       64374   52  Female      45               15              9
#
#        Payment Delay Subscription Type Contract Length  Total Spend  \
# ...

# %%
df.head(4)
# Out:
#    CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0           1   22  Female      25               14              4
# 1           2   41  Female      28               28              7
# 2           3   47    Male      27               10              2
# 3           4   35    Male       9               12              5
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0             27             Basic         Monthly        598.0
# 1             13          Standard         Monthly        584.0
# 2             29           Premium          Annual        757.0
# 3             17           Premium       Quarterly        232.0
#
#    Last Interaction  Churn
# 0                 9      1
# 1                20      0
# 2                21      0
# 3                18      0

# %%
df.dtypes
# Out:
# CustomerID             int64
# Age                    int64
# Gender                object
# Tenure                 int64
# Usage Frequency        int64
# Support Calls          int64
# Payment Delay          int64
# Subscription Type     object
# Contract Length       object
# Total Spend          float64
# Last Interaction       int64
# Churn                  int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score

# %%
df.isnull().sum()
# Out:
# CustomerID            0
# Age                   0
# Gender                0
# Tenure                0
# Usage Frequency       0
# Support Calls         0
# Payment Delay         0
# Subscription Type     0
# Contract Length       0
# Total Spend          34
# Last Interaction      0
# Churn                 0
# dtype: int64

# %%
gender_churn = df.groupby(['Gender', 'Churn']).size().unstack()
gender_churn.plot(kind='bar', stacked=True, color=['#1f7777', '#ff7f0e']) 
plt.title('Gender vs Churn')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
gender_subscription = df.groupby(['Gender', 'Subscription Type']).size().unstack()
gender_subscription.plot(kind='bar', stacked=True, color=['#2ca02c', '#d67828', '#9467bd'])  # Green, Red, Purple
plt.title('Gender vs Subscription Type')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
age_churn = df.groupby(['Age', 'Churn']).size().unstack()
age_churn.plot(kind='bar', width=0.4, stacked=True, color=['#6d564b', '#e377c2'])  # Brown & Pink
plt.title('Age vs Churn')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({x_label: grp['Contract Length'].value_counts() for x_label, grp in df.groupby('Subscription Type')})
sns.heatmap(df_2dhist, cmap='coolwarm')

plt.xlabel('Subscription Type')
plt.ylabel('Contract Length')
plt.show()
